# %% [markdown]
# <a href="https://colab.research.google.com/github/adityacaroli/k-means-clustering/blob/master/task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import io

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e17864fe-8425-4bca-8d9b-357b20b3fdcd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e17864fe-8425-4bca-8d9b-357b20b3fdcd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving date1.txt to date1.txt

# %%
df = pd.read_csv(io.BytesIO(uploaded['date1.txt']))

# %%
df.head()
# Out:
#              Payment date
# 0  16-03-2020 12:00:00 AM
# 1  16-03-2020 12:00:00 AM
# 2  16-03-2020 12:00:00 AM
# 3  16-03-2020 12:00:00 AM
# 4  17-03-2020 12:00:00 AM

# %%
df['Payment date'][0].split(' ')[0]
# Out:
# '16-03-2020'

# %%
df['date'] = df['Payment date'].apply(lambda x: x.split(' ')[0])
df
# Out:
#                Payment date        date
# 0    16-03-2020 12:00:00 AM  16-03-2020
# 1    16-03-2020 12:00:00 AM  16-03-2020
# 2    16-03-2020 12:00:00 AM  16-03-2020
# 3    16-03-2020 12:00:00 AM  16-03-2020
# 4    17-03-2020 12:00:00 AM  17-03-2020
# 5    17-03-2020 12:00:00 AM  17-03-2020
# 6    17-03-2020 12:00:00 AM  17-03-2020
# 7    17-03-2020 12:00:00 AM  17-03-2020
# 8    17-03-2020 12:00:00 AM  17-03-2020
# 9    17-03-2020 12:00:00 AM  17-03-2020
# 10   18-03-2020 12:00:00 AM  18-03-2020
# 11   18-03-2020 12:00:00 AM  18-03-2020
# 12   18-03-2020 12:00:00 AM  18-03-2020
# 13   18-03-2020 12:00:00 AM  18-03-2020
# 14   18-03-2020 12:00:00 AM  18-03-2020
# 15   18-03-2020 12:00:00 AM  18-03-2020
# 16   18-03-2020 12:00:00 AM  18-03-2020
# 17   18-03-2020 12:00:00 AM  18-03-2020
# 18   18-03-2020 12:00:00 AM  18-03-2020
# 19   18-03-2020 12:00:00 AM  18-03-2020
# 20   19-03-2020 12:00:00 AM  19-03-2020
# 21   19-03-2020 12:00:00 AM  19-03-2020
# ...

# %%
df.dtypes
# Out:
# Payment date    object
# date            object
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])
df.head()
# Out:
#              Payment date       date
# 0  16-03-2020 12:00:00 AM 2020-03-16
# 1  16-03-2020 12:00:00 AM 2020-03-16
# 2  16-03-2020 12:00:00 AM 2020-03-16
# 3  16-03-2020 12:00:00 AM 2020-03-16
# 4  17-03-2020 12:00:00 AM 2020-03-17

# %%
df.dtypes
# Out:
# Payment date            object
# date            datetime64[ns]
# dtype: object
